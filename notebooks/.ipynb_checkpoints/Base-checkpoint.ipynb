# %% [markdown]
# ## Introduction to Gated Recurrent Neural Network

# %% [markdown]
# In this blog we are going to understand:
# - What a Gated Recurrent Neural Network (GRU) is?
# - What is the theory behind it?
# - How does the architecture look like?
# - What makes it so different from a traditional neural network?
#
# This will enable us to apply GRUs (just like RNNs, GRUs, LSTMs) to problem related to sequence classification (ex: audio, text, video)
#
# So, understanding this thery will set the grounds to (understand, implement, identify problems/use-cases where we can actually use these models)

# %% [markdown]
# ### What is the motivation?
#
# For example, if you're reading a newspaper, you will read several sentences after which you stop and try to guess the next suitable word that will fit well in that context. The reason why you can predict the next word with relatively high accuracy is because you remember what you read before (you don't throw everything away and start thinking from scratch again) as our thoughts always have some sort of persistance - we remember what happend previously. Because of that, we're able to predict what will happen next.
#
# But, traditional neural network cannot do this, and that's a very big shortcoming.
#
# For example, if you want to classify what kind of event is happening at every point in a movie. It's unclear to a traiditional neural network, because it doesn't maintain that state of previous events. Since it doesn't know what happend before, it is impossible for it to predict what will happen next.

# %% [markdown]
# Recurrent Neural Networks (RNNs) address this issue.
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202022-06-20%20%D0%B2%2014.13.35.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202022-06-20%20%D0%B2%2014.13.35.png)
# In the picture, we can see that in contrast to the traditional feed-forward neural network, in each node of the recurrent neural network there is a loop. These loops help us to retain/persist information.
#
# In contrast, in the traditional feed-forward neural network, whatever comes from the previous step just get forwarded to the next step and that node is not able to retain anything.
#
# This retention of infrmation is the differentiating point between a (Recurrent Neural Network) and (Traditional Feed-Forward Recurrent Neural Network).
#
# Consequently, RNNs are very suitable models for problems related to sequences, where remembering what happend before is essential what will happen next (ex: predicting the next word in a sentence).
#
# Consequently, given (some book, movie script or any kind of text corpus), use can use it to feed it into a RNNs and in turn it will learn how to generate words in the style of that corpus of text.
#
# To understand mathematics behind RNNs I would recommend watching this [video from Stanford University School Of Engineering](https://www.youtube.com/watch?v=6niqTuYFZLQ).

# %% [markdown]
# ### Why not Deep Neural Networks?
